# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

# %%
def resize(image, w, h):
  image=cv2.resize(image,(w,h))
  return image
def gausblur(image, blur, m):
  image = cv2.GaussianBlur(image,(m,m), blur)
  return image
def avgblur (image, shift):
  image=cv2.blur(image,(shift, shift))
  return image

# %%
from google.colab import files
import cv2

file = files.upload()
# Out:
#      <input type="file" id="files-1e902f68-0e7d-49ef-8ff8-75e432d6e400" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e902f68-0e7d-49ef-8ff8-75e432d6e400">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2022-03-01 at 22.54.23.jpeg to WhatsApp Image 2022-03-01 at 22.54.23 (1).jpeg

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('WhatsApp Image 2022-03-01 at 22.54.23.jpeg')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEAA9CD0>

# %%
fig = plt.figure()
fig.add_subplot(121)

img = cv2.flip(img, 1)

plt.imshow(img)

fig.add_subplot(122)

img1 = cv2.imread('WhatsApp Image 2022-03-01 at 22.54.23.jpeg')
img1 = cv2.flip(img1, 1)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

plt.imshow(img1)
plt.show()
cv2.waitKey()
# Out:
# -1

# %%
img = cv2.imread('WhatsApp Image 2022-03-01 at 22.54.23.jpeg')
x = gausblur(img, 5, 5)
y = avgblur(img, 8)
cv2_imshow(img)
cv2_imshow(x)
cv2_imshow(y)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEA2FC50>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEB12310>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEA2F710>
# -1

# %%
#KONVERSI WARNA GAMBAR
abu = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

cv2_imshow(abu)
cv2_imshow(RGB)
cv2_imshow(HSV)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FADFEAFF150>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEAFF4D0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEAFFD90>

# %%
#MEMISAHKAN CHANNEL BGR
B, G, R = cv2.split(img)
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)

gabung = cv2.merge([B, G, R])
cv2_imshow(gabung)

gabung1 = cv2.merge([R, G, B])
cv2_imshow(gabung1)

gabung2 = cv2.merge([G, B, R])
cv2_imshow(gabung2)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FADFEA31510>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FADFEA315D0>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FADFEA31A90>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEA31350>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEA31950>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFEA315D0>

# %%
H, S, V = cv2.split(img)
cv2_imshow(H)
cv2_imshow(S)
cv2_imshow(V)

gabung3 = cv2.merge([H,S,V])
cv2_imshow(gabung3)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FADFE0DAE10>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FADFE20DA90>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FADFE0DABD0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FADFE20DA90>
